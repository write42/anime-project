# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
anime_df = pd.read_csv('anime.csv')

# %%
anime_df
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %%
genre_categories = anime_df['genre'].unique()

# %%
genre_categories
# Out:
# array(['Drama, Romance, School, Supernatural',
#        'Action, Adventure, Drama, Fantasy, Magic, Military, Shounen',
#        'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#        ..., 'Hentai, Sports', 'Drama, Romance, School, Yuri',
#        'Hentai, Slice of Life'], dtype=object)

# %%
anime_df.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
anime_type = anime_df['type'].unique()

# %%
anime_type
# Out:
# array(['Movie', 'TV', 'OVA', 'Special', 'Music', 'ONA', nan], dtype=object)

# %%
anime_df.shape
# Out:
# (12294, 7)

# %%
anime_df.count()
# Out:
# anime_id    12294
# name        12294
# genre       12232
# type        12269
# episodes    12294
# rating      12064
# members     12294
# dtype: int64

# %%
anime_clean_df = anime_df.dropna()

# %%
anime_clean_df.count()
# Out:
# anime_id    12017
# name        12017
# genre       12017
# type        12017
# episodes    12017
# rating      12017
# members     12017
# dtype: int64

# %%
second_clean_df_split = anime_clean_df['genre'].str.split(', ', expand=True)

# %%
second_clean_df_split
# Out:
#            0          1           2             3        4         5   \
# 0       Drama    Romance      School  Supernatural     None      None
# 1      Action  Adventure       Drama       Fantasy    Magic  Military
# 2      Action     Comedy  Historical        Parody  Samurai    Sci-Fi
# 3      Sci-Fi   Thriller        None          None     None      None
# 4      Action     Comedy  Historical        Parody  Samurai    Sci-Fi
# ...       ...        ...         ...           ...      ...       ...
# 12289  Hentai       None        None          None     None      None
# 12290  Hentai       None        None          None     None      None
# 12291  Hentai       None        None          None     None      None
# 12292  Hentai       None        None          None     None      None
# 12293  Hentai       None        None          None     None      None
#
#             6     7     8     9     10    11    12
# 0         None  None  None  None  None  None  None
# 1      Shounen  None  None  None  None  None  None
# 2      Shounen  None  None  None  None  None  None
# 3         None  None  None  None  None  None  None
# 4      Shounen  None  None  None  None  None  None
# ...        ...   ...   ...   ...   ...   ...   ...
# 12289     None  None  None  None  None  None  None
# 12290     None  None  None  None  None  None  None
# 12291     None  None  None  None  None  None  None
# 12292     None  None  None  None  None  None  None
# 12293     None  None  None  None  None  None  None
#
# [12017 rows x 13 columns]

# %%
df_w_genres = pd.concat([anime_clean_df, second_clean_df_split],axis=1)

# %%
df_w_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12017 entries, 0 to 12293
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12017 non-null  int64
#  1   name      12017 non-null  object
#  2   genre     12017 non-null  object
#  3   type      12017 non-null  object
#  4   episodes  12017 non-null  object
#  5   rating    12017 non-null  float64
#  6   members   12017 non-null  int64
#  7   0         12017 non-null  object
#  8   1         9250 non-null   object
#  9   2         6618 non-null   object
#  10  3         4063 non-null   object
#  11  4         2167 non-null   object
#  12  5         931 non-null    object
#  13  6         351 non-null    object
#  14  7         126 non-null    object
#  15  8         53 non-null     object
#  16  9         14 non-null     object
#  17  10        3 non-null      object
#  18  11        1 non-null      object
#  19  12        1 non-null      object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.9+ MB

# %%
df_w_genres.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members       0          1           2             3        4         5  \
# 0   200630   Drama    Romance      School  Supernatural     None      None
# 1   793665  Action  Adventure       Drama       Fantasy    Magic  Military
# 2   114262  Action     Comedy  Historical        Parody  Samurai    Sci-Fi
# 3   673572  Sci-Fi   Thriller        None          None     None      None
# 4   151266  Action     Comedy  Historical        Parody  Samurai    Sci-Fi
#
#          6     7     8     9    10    11    12
# 0     None  None  None  None  None  None  None
# 1  Shounen  None  None  None  None  None  None
# 2  Shounen  None  None  None  None  None  None
# 3     None  None  None  None  None  None  None
# 4  Shounen  None  None  None  None  None  None

# %%
df_w_genres[df_w_genres['genre'].str.contains("Hentai")==False]
# Out:
#        anime_id                              name  \
# 0         32281                    Kimi no Na wa.
# 1          5114  Fullmetal Alchemist: Brotherhood
# 2         28977                          Gintama°
# 3          9253                       Steins;Gate
# 4          9969                     Gintama&#039;
# ...         ...                               ...
# 12128      9600                    G-Taste (2010)
# 12193      2592                            Kimera
# 12203       730          Houkago no Shokuinshitsu
# 12207      6546      Pico: My Little Summer Story
# 12214     30663                    Docchi mo Maid
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12128                                        Ecchi, Yuri    OVA        1
# 12193  Action, Horror, Sci-Fi, Supernatural, Vampire,...    OVA        1
# 12203                               Drama, Romance, Yaoi    OVA        2
# 12207                                               Yaoi    OVA        1
# 12214                        Action, Comedy, Ecchi, Yuri    ONA        1
#
#        rating  members       0          1           2             3        4  \
# 0        9.37   200630   Drama    Romance      School  Supernatural     None
# 1        9.26   793665  Action  Adventure       Drama       Fantasy    Magic
# 2        9.25   114262  Action     Comedy  Historical        Parody  Samurai
# 3        9.17   673572  Sci-Fi   Thriller        None          None     None
# 4        9.16   151266  Action     Comedy  Historical        Parody  Samurai
# ...       ...      ...     ...        ...         ...           ...      ...
# 12128    5.49     1445   Ecchi       Yuri        None          None     None
# 12193    5.29     3374  Action     Horror      Sci-Fi  Supernatural  Vampire
# 12203    5.23     4550   Drama    Romance        Yaoi          None     None
# 12207    5.21     5551    Yaoi       None        None          None     None
# 12214    5.15      223  Action     Comedy       Ecchi          Yuri     None
#
#               5        6     7     8     9    10    11    12
# 0          None     None  None  None  None  None  None  None
# 1      Military  Shounen  None  None  None  None  None  None
# 2        Sci-Fi  Shounen  None  None  None  None  None  None
# 3          None     None  None  None  None  None  None  None
# 4        Sci-Fi  Shounen  None  None  None  None  None  None
# ...         ...      ...   ...   ...   ...   ...   ...   ...
# 12128      None     None  None  None  None  None  None  None
# 12193      Yaoi     None  None  None  None  None  None  None
# 12203      None     None  None  None  None  None  None  None
# 12207      None     None  None  None  None  None  None  None
# 12214      None     None  None  None  None  None  None  None
#
# [10884 rows x 20 columns]

# %%
#second_clean_anime_df = pd.concat([anime_clean_df['genre'], anime_clean_df[1].str.split(',',expand=True)],axis=1)
